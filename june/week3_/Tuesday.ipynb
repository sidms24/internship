# %% [markdown]
# <a href="https://colab.research.google.com/github/sidms24/internship/blob/main/june/week3_/Tuesday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://raw.githubusercontent.com/sidms24/internship/refs/heads/main/phenome_20250617.tsv?token=GHSAT0AAAAAACV2FL2VP554DI47QRSWSNDY2CRKBMA
# Out:
# --2025-06-17 11:23:27--  https://raw.githubusercontent.com/sidms24/internship/refs/heads/main/phenome_20250617.tsv?token=GHSAT0AAAAAACV2FL2VP554DI47QRSWSNDY2CRKBMA
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 169987 (166K) [text/plain]
# Saving to: ‘phenome_20250617.tsv?token=GHSAT0AAAAAACV2FL2VP554DI47QRSWSNDY2CRKBMA’
#
# phenome_20250617.ts 100%[===================>] 166.00K  --.-KB/s    in 0.02s
#
# 2025-06-17 11:23:27 (7.41 MB/s) - ‘phenome_20250617.tsv?token=GHSAT0AAAAAACV2FL2VP554DI47QRSWSNDY2CRKBMA’ saved [169987/169987]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/phenome_20250617.tsv', sep='\t')

# %%
df
# Out:
#         #NGB ID Accession ID     CNSA ID  Homogeneity Seed color  \
# 0    NGBLS00001      TKI-001  CNS0047843  homogeneous      white
# 1    NGBLS00002      TKI-002  CNS0047569  homogeneous      black
# 2    NGBLS00003      TKI-003  CNS0047893  homogeneous      white
# 3    NGBLS00004      TKI-004  CNS0047868  homogeneous      white
# 4    NGBLS00005      TKI-006  CNS0047930  homogeneous      white
# ..          ...          ...         ...          ...        ...
# 440  NGBLS00456      TKI-476  CNS0252039           --      black
# 441  NGBLS00457      TKI-477  CNS0047628           --      black
# 442  NGBLS00459      TKI-481  CNS0252040           --         --
# 443  NGBLS00461      TKI-494  CNS0047526           --         --
# 444  NGBLS00462      TKI-495  CNS0047775           --         --
#
#     Seedling size    Seedling cotyledon shape Seedling cotyledon color  \
# 0           large  broad elliptic to circular              light green
# ...
